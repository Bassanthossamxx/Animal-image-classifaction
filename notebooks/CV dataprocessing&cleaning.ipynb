# %% [markdown]
# # Notebook Index
#
# This notebook now acts as a redirect to the project deliverables.
#
# Run the notebooks in this order:
#
# 1. `1_data_exploration.ipynb`
# 2. `2_model_training.ipynb`
# 3. `3_evaluation.ipynb`

# %% [markdown]
# ## Dataset Convention
#
# Expected local dataset root: `../data/animals_dataset/`
#
# - `train/`
# - `val/`
# - `test/`
#
# Classes used throughout the project:
#
# - `cat`
# - `cow`
# - `deer`
# - `dog`
# - `lion`
